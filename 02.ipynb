# %% [markdown]
# <a href="https://colab.research.google.com/github/mahdidanishjo53-jpg/Intro_Repository-/blob/main/02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!-- Slide 1: What is a Variable? -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Variables in Python
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **What is a Variable?**
# - A container that stores information
# - Like a labeled box holding data
# - You can create, read, and change variables
#
# **Creating Variables**
# - Use a name and assign a value with =
# - Example: `name = "Ahmed"` or `age = 25`
# - Names should be meaningful and simple
#
# **Variable Naming Rules**
# - Start with a letter or underscore (_)
# - Use letters, numbers, and underscores only
# - No spaces or special characters
# - Good names: `my_name`, `student_age`, `total_score`
# </div>
# </div>
#
# <!-- Slide 2: Data Types in Python -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Data Types in Python
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **String (str)** - Text data
# - `name = "Ahmed"`
# - `city = "Hamburg"`
#
# **Integer (int)** - Whole numbers
# - `age = 25`
# - `score = 100`
#
# **Float (float)** - Decimal numbers
# - `height = 1.75`
# - `temperature = 23.5`
#
# **Boolean (bool)** - True or False
# - `is_student = True`
# - `is_online = False`
#
# Python automatically knows the data type!
# </div>
# </div>
#
# <!-- Slide 3: Working with Strings -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Working with Strings
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Combining Strings**
# - `first_name = "Ahmed"`
# - `last_name = "Khan"`
# - `full_name = first_name + " " + last_name`
#
# **String Length**
# - `text = "Python"`
# - `length = len(text)` → 6
#
# **Changing Case**
# - `text.upper()` → "PYTHON"
# - `text.lower()` → "python"
#
# **Finding Characters**
# - `text[0]` → "P" (first character)
# - `text[1]` → "y" (second character)
# </div>
# </div>
#
# <!-- Slide 4: Math Operations -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Math Operations
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Basic Math**
# - Addition: `5 + 3` → 8
# - Subtraction: `10 - 2` → 8
# - Multiplication: `4 * 5` → 20
# - Division: `20 / 4` → 5.0
#
# **Using Variables**
# - `age = 25`
# - `next_year = age + 1` → 26
# - `double_age = age * 2` → 50
#
# **Order of Operations**
# - `2 + 3 * 4` → 14 (multiplication first)
# - `(2 + 3) * 4` → 20 (parentheses first)
# </div>
# </div>
#
# <!-- Slide 5: Updating Variables -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Updating Variables
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Changing a Value**
# - `score = 80`
# - `score = 90` (old value replaced)
# - Variable now holds 90
#
# **Quick Update**
# - `score = score + 10` (add 10 to current value)
# - `score += 10` (same thing, shorter way)
# - `score -= 5` (subtract 5)
#
# **Swapping Values**
# - `a = 5`
# - `b = 10`
# - `a, b = b, a` (swap them)
# - Now: a = 10, b = 5
#
# Variables are flexible and can change anytime!
# </div>
# </div>

# %% [markdown]
# <!-- Slide 6: Lists - Storing Multiple Values -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Lists - Storing Multiple Values
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **What is a List?**
# - A container that holds multiple items
# - Items are ordered and can be changed
# - Use square brackets: `[ ]`
#
#
# **Creating Lists**
# - `fruits = ["apple", "banana", "orange"]`
# - `numbers = [1, 5, 10, 25, 100]`
# - `mixed = [1, "hello", 3.14, True]`
#
#
# **Accessing Items**
# - `fruits[0]` → "apple" (first item)
# - `fruits[1]` → "banana" (second item)
# - `fruits[-1]` → "orange" (last item)
#
#
# **List Length**
# - `len(fruits)` → 3
# </div>
# </div>
#
# <!-- Slide 7: Working with Lists -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Working with Lists
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Adding Items**
# - `fruits = ["apple", "banana"]`
# - `fruits.append("orange")` → ["apple", "banana", "orange"]
#
#
# **Removing Items**
# - `fruits.remove("banana")` → removes "banana"
# - `fruits.pop()` → removes last item
# - `fruits.pop(0)` → removes first item
#
#
# **Changing Items**
# - `fruits[0] = "grape"` → changes first item
#
#
# **Looping Through Lists**
# - `for fruit in fruits:`
# - `    print(fruit)` → prints each fruit
#
# </div>
# </div>
#
# <!-- Slide 8: Dictionaries - Key and Value Pairs -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Dictionaries - Key and Value Pairs
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **What is a Dictionary?**
# - Stores data with labels (keys) and values
# - Like a real dictionary: word → meaning
# - Use curly brackets: `{ }`
#
#
# **Creating Dictionaries**
# - `student = {"name": "Ahmed", "age": 25, "city": "Hamburg"}`
# - `grades = {"math": 95, "english": 88, "science": 92}`
#
#
# **Accessing Values**
# - `student["name"]` → "Ahmed"
# - `grades["math"]` → 95
#
#
# **Adding New Pairs**
# - `student["email"] = "ahmed@example.com"`
#
#
# **Changing Values**
# - `student["age"] = 26`
#
# </div>
# </div>
#
# <!-- Slide 9: Conditional Statements - If, Else -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Conditional Statements - If, Else
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Basic If Statement**
# - `age = 18`
# - `if age >= 18:`
# - `    print("You are an adult")`
#
#
# **If-Else Statement**
# - `if age >= 18:`
# - `    print("Adult")`
# - `else:`
# - `    print("Not an adult")`
#
#
# **Comparison Operators**
# - `==` equal to
# - `!=` not equal to
# - `<` less than
# - `>` greater than
# - `<=` less than or equal
# - `>=` greater than or equal
#
#
# **If-Elif-Else**
# - `if score >= 90: print("A")`
# - `elif score >= 80: print("B")`
# - `else: print("C")`
#
# </div>
# </div>
#
# <!-- Slide 10: Logical Operators -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Logical Operators - and, or, not
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Using AND**
# - Both conditions must be True
# - `age = 25`
# - `if age >= 18 and age < 65:`
# - `    print("Working age")`
#
#
# **Using OR**
# - At least one condition must be True
# - `day = "Saturday"`
# - `if day == "Saturday" or day == "Sunday":`
# - `    print("It's weekend!")`
#
#
# **Using NOT**
# - Reverses the condition
# - `is_raining = False`
# - `if not is_raining:`
# - `    print("Let's go outside!")`
#
#
# **Combining Multiple Conditions**
# - `if age >= 18 and has_license and not is_tired:`
# - `    print("You can drive")`
#
# </div>
# </div>
#
# <!-- Slide 11: Loops - For Loop -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Loops - For Loop
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Looping Through a List**
# - `fruits = ["apple", "banana", "orange"]`
# - `for fruit in fruits:`
# - `    print(fruit)`
#
#
# **Using Range**
# - `for i in range(5):` → loops 0, 1, 2, 3, 4
# - `for i in range(1, 6):` → loops 1, 2, 3, 4, 5
# - `for i in range(0, 10, 2):` → loops 0, 2, 4, 6, 8
#
#
# **Looping and Counting**
# - `total = 0`
# - `for number in [1, 2, 3, 4, 5]:`
# - `    total = total + number`
# - `print(total)` → 15
#
#
# **Break and Continue**
# - `break` stops the loop
# - `continue` skips to next iteration
#
# </div>
# </div>
#
# <!-- Slide 12: Loops - While Loop -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Loops - While Loop
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Basic While Loop**
# - Repeats as long as condition is True
# - `count = 0`
# - `while count < 5:`
# - `    print(count)`
# - `    count = count + 1`
#
#
# **Counting Down**
# - `number = 5`
# - `while number > 0:`
# - `    print(number)`
# - `    number -= 1`
#
#
# **User Input Loop**
# - `password = ""`
# - `while password != "secret":`
# - `    password = input("Enter password: ")`
#
#
# **Be Careful!**
# - Infinite loop: `while True:` with no break
# - Always update the variable in the loop
# - Use `break` to exit when needed
#
# </div>
# </div>
#
# <!-- Slide 13: Functions - Creating Reusable Code -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Functions - Creating Reusable Code
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **What is a Function?**
# - A block of code that does a specific task
# - You can call it many times
# - Saves time and makes code cleaner
#
#
# **Creating a Simple Function**
# - `def greet():`
# - `    print("Hello, friend!")`
# - `greet()` → calls the function
#
#
# **Functions with Parameters**
# - `def greet(name):`
# - `    print("Hello, " + name)`
# - `greet("Ahmed")` → prints "Hello, Ahmed"
#
#
# **Functions with Return**
# - `def add(a, b):`
# - `    return a + b`
# - `result = add(5, 3)` → result = 8
#
#
# **Multiple Parameters**
# - `def introduce(name, age, city):`
# - `    print(f"{name} is {age} years old from {city}")`
#
# </div>
# </div>
#
# <!-- Slide 14: String Formatting and Input -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# String Formatting and User Input
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **String Formatting (f-strings)**
# - `name = "Ahmed"`
# - `age = 25`
# - `print(f"{name} is {age} years old")`
#
#
# **Getting User Input**
# - `name = input("What is your name? ")`
# - `age = input("How old are you? ")`
# - input() always returns a string
#
#
# **Converting Input to Numbers**
# - `age = int(input("How old are you? "))`
# - `height = float(input("Your height in meters? "))`
#
#
# **Simple Program Example**
# - `name = input("Enter your name: ")`
# - `age = int(input("Enter your age: "))`
# - `print(f"Welcome {name}! Next year you'll be {age + 1}")`
#
# </div>
# </div>
#
# <!-- Slide 15: Working with Files -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Working with Files
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Reading a File**
# - `file = open("data.txt", "r")`
# - `content = file.read()`
# - `file.close()`
#
#
# **Better Way - Using With**
# - `with open("data.txt", "r") as file:`
# - `    content = file.read()`
# - (file closes automatically)
#
#
# **Writing to a File**
# - `with open("output.txt", "w") as file:`
# - `    file.write("Hello World!")`
#
#
# **Appending to a File**
# - `with open("log.txt", "a") as file:`
# - `    file.write("New entry\n")`
#
#
# **File Modes**
# - `"r"` read mode
# - `"w"` write mode (overwrites)
# - `"a"` append mode (adds to end)
#
# </div>
# </div>

# %%
A=10 # integer
print(A)
B=1.2 # FLOAT
Name="Ali" # STRING
First_name= "Ali"
Last_name ="Mahmoodi"
Full_name= First_name + "" + Last_name
# Out:
# 10

# %%
D=1.23
print(D)
# Out:
# 1.23

# %%
Name="Ahmad"
print(Name)
# Out:
# Ahmad

# %%
Text="Python"
Text[5]
# Out:
# 'n'

# %%
Text="PYTHON"
Text.lower()
# Out:
# 'python'

# %%
A= 5
B=10
C=A+B
print(A+B)
# Out:
# 15

# %%
D=20
E=100
print(E-D)
# Out:
# 80

# %%
A=2
B=4
C=A*B
print(C)
# Out:
# 8

# %%
A=100
B=20
C=A/B
print(C)
# Out:
# 5.0

# %%
A=20
B=2
C=10
D=C**B
print(D)
# Out:
# 100

# %%
A=100
B=A
print(B)
# Out:
# 100

# %%
age = 18

if age >= 18:
    print("You are an adult.")

# %%
temperature = 30

if temperature > 25:
    print("It's hot outside.")
else:
    print("It's cool outside.")

# %%
score = 85

if score >= 90:
    print("Grade A")
elif score >= 80:
    print("Grade B")
elif score >= 70:
    print("Grade C")
else:
    print("Grade F")

# %%
username = "admin"
password = "1234"

if username == "admin" and password == "1234":
    print("Access granted.")
else:
    print("Access denied.")

# %%
numbers = [1, 2, 3, 4, 5]

for num in numbers:
    if num % 2 == 0:
        print(num, "is even")
